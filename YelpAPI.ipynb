# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Peach\anaconda3\envs\dojo-env\python.exe

# %%
from yelpapi import YelpAPI
import pandas as pd
import json

# %%
with open('/Users/Peach/Documents/Dojo-env/dojo-env-setup/Stack4/Week2/APICallEfficacy/.hidden/yelpi.json', 'r') as f:
    yl = json.load(f)

# %%
y_a = YelpAPI(yl['api_key'], timeout_s=3.1)

# %%
location = 'New York, NY'
term = 'Italian'
categories = 'restaurants'
iterlim = 20
radius = 5

# %%
results = []

for offset in range(0, 1001, iterlim):
    rep = y_a.search_query(term=term, location=location, category=categories)
    
    results += rep['businesses']

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#                           id                                alias  \
# 0     hdiuRS9sVZSMReZm4oV5SA                   da-andrea-new-york
# 1     16ZnHpuaaBt92XWeJHCC5A                olio-e-più-new-york-7
# 2     WG639VkTjmK5dzydd1BBJA                  rubirosa-new-york-2
# 3     OCTiJwvjoK81WoDwsTkFvA  paesano-of-mulberry-street-new-york
# 4     qBGKigOGn_flCx1apxPzlA    piccola-cucina-osteria-new-york-2
# ...                      ...                                  ...
# 1015  ysqgdbSrezXgVwER2kQWKA                  julianas-brooklyn-3
# 1016  h37t9rA06Sr4EetJjKrfzw                   don-angie-new-york
# 1017  KCBfW6sWl9Gx-LvMff08jg            osteria-morini-new-york-3
# 1018  hpRrYBbKUqv8ewFKDjbjoA                       gersi-brooklyn
# 1019  Be1Y-vAEMgo7lqL5alXgDA            taverna-di-bacco-new-york
#
#                             name  \
# 0                      Da Andrea
# 1                     Olio e Più
# 2                       Rubirosa
# 3     Paesano of Mulberry Street
# ...
